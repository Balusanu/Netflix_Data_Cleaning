# %% [markdown]
# ## Netflix Data cleaning

# %% [markdown]
# In this Project we are going to load the "netflix1" CSV file & perform following Data cleaning steps
# 1) Removing redundant columns
# 2) Renaming columns
# 3) Dropping duplicates
# 4) removing NaN( null) values from Data
# 5) Check for some more transormations

# %%
## importing the Pandas library
import pandas as pd

# %%
## loading the CSV file
data = pd.read_csv("netflix1.csv")

# %%
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
data.shape ## Data has 10 columns & 8790 rows
# Out:
# (8790, 10)

# %%
data.head() ##Shows first five rows with columns
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %% [markdown]
# 1) Removing redundant columns

# %%
data.columns ##shows all the column names
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
data.drop(columns="rating",inplace=True) ##we are dropping rating column as it is not much use

# %%
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year   duration  \
# ...

# %% [markdown]
# 2) Renaming columns

# %%
data.columns ## we need to capitalise each column name
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'duration', 'listed_in'],
#       dtype='object')

# %%
## we can do it using a loop
new_columns_names = []
for i in data.columns:
   new_columns_names.append(i.capitalize())

data.columns = new_columns_names

# %%
data.columns
# Out:
# Index(['Show_id', 'Type', 'Title', 'Director', 'Country', 'Date_added',
#        'Release_year', 'Duration', 'Listed_in'],
#       dtype='object')

# %%
data.head()
# Out:
#   Show_id     Type                             Title         Director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year  Duration  \
# 0  United States  9/25/2021          2020    90 min
# 1         France  9/24/2021          2021  1 Season
# 2  United States  9/24/2021          2021  1 Season
# 3         Brazil  9/22/2021          2021    91 min
# 4  United States  9/24/2021          1993   125 min
#
#                                            Listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# ...

# %% [markdown]
# 3) Dropping duplicates

# %%
## checking for duplicate entries in the data
data.duplicated().sum() ## There are no duplicate entries in the data
# Out:
# np.int64(0)

# %% [markdown]
# 4) removing NaN( null) values from Data

# %%
## checking for NaN entries in the data
data.isna().sum() ## There are no NaN entries in the data
# Out:
# Show_id         0
# Type            0
# Title           0
# Director        0
# Country         0
# Date_added      0
# Release_year    0
# Duration        0
# Listed_in       0
# dtype: int64

# %% [markdown]
# 5) Check for some more transormations

# %%
## Removing "s" string from Show_id column
data["Show_id"].unique()
# Out:
# array(['s1', 's3', 's6', ..., 's8801', 's8784', 's8786'], dtype=object)

# %%
data["Show_id"] = data["Show_id"].apply(lambda x: x.split("s")[1])

# %%
data
# Out:
#      Show_id     Type                             Title         Director  \
# 0          1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1          3  TV Show                         Ganglands  Julien Leclercq
# 2          6  TV Show                     Midnight Mass    Mike Flanagan
# 3         14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4          8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785    8797  TV Show                        Yunus Emre        Not Given
# 8786    8798  TV Show                         Zak Storm        Not Given
# 8787    8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788    8784  TV Show                              Yoko        Not Given
# 8789    8786  TV Show                               YOM        Not Given
#
#             Country  Date_added  Release_year   Duration  \
# ...

# %%
## changing the  data type of Show_id to int
type(data["Show_id"][0])
# Out:
# str

# %%
data["Show_id"] = data["Show_id"].astype(int)

# %%
type(data["Show_id"][0])
# Out:
# numpy.int64

# %%
data.head()
# Out:
#    Show_id     Type                             Title         Director  \
# 0        1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1        3  TV Show                         Ganglands  Julien Leclercq
# 2        6  TV Show                     Midnight Mass    Mike Flanagan
# 3       14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4        8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_added  Release_year  Duration  \
# 0  United States  9/25/2021          2020    90 min
# 1         France  9/24/2021          2021  1 Season
# 2  United States  9/24/2021          2021  1 Season
# 3         Brazil  9/22/2021          2021    91 min
# 4  United States  9/24/2021          1993   125 min
#
#                                            Listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# ...

# %%
## replacing "/" in Date_added column with "-"
data["Date_added"] = data["Date_added"].apply(lambda x:x.replace("/","-"))

# %%
## We are going to export the cleaned in CSV & XLSX format
data.to_csv("Netflix_Cleaned_data.csv",index=False)
data.to_excel("Netflix_Cleaned_data.xlsx",index=False)
